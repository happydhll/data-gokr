# %%
import requests

# %%
#url ='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev
#?serviceKey=&pageNo=1&numOfRows=10&LAWD_CD=11110&DEAL_YMD=201512'
#url ='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey=E241JwGDBlWU%2FODcDpeLlioKso2%2B6UmZDG7VlUaud2oS2XRIu7BOg%2BUetlydPFtcfDuJ02YDvC5F7ZjSynRfEA%3D%3D&pageNo=1&numOfRows=10&LAWD_CD=11110&DEAL_YMD=201512'
url ='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev'
mykey = 'E241JwGDBlWU%2FODcDpeLlioKso2%2B6UmZDG7VlUaud2oS2XRIu7BOg%2BUetlydPFtcfDuJ02YDvC5F7ZjSynRfEA%3D%3D'
l_pageno = '1'
l_numofrows = '10'
l_lawd_cd = '11680'
l_deal_ymd = '202212'
#param = f'?ServiceKey={mykey}&pageNo=1&numOfRows=10&LAWD_CD=11110&DEAL_YMD=201512'
param = f'?ServiceKey={mykey}&pageNo={l_pageno}&numOfRows={l_numofrows}&LAWD_CD={l_lawd_cd}&DEAL_YMD={l_deal_ymd}'


resp = requests.get(url+param)
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><\xea\xb1\xb0\xeb\x9e\x98\xea\xb8\x88\xec\x95\xa1>    74,000</\xea\xb1\xb0\xeb\x9e\x98\xea\xb8\x88\xec\x95\xa1><\xea\xb1\xb0\xeb\x9e\x98\xec\x9c\xa0\xed\x98\x95>\xec\xa4\x91\xea\xb0\x9c\xea\xb1\xb0\xeb\x9e\x98</\xea\xb1\xb0\xeb\x9e\x98\xec\x9c\xa0\xed\x98\x95><\xea\xb1\xb4\xec\xb6\x95\xeb\x85\x84\xeb\x8f\x84>2004</\xea\xb1\xb4\xec\xb6\x95\xeb\x85\x84\xeb\x8f\x84><\xeb\x85\x84>2022</\xeb\x85\x84><\xeb\x8f\x84\xeb\xa1\x9c\xeb\xaa\x85>\xed\x85\x8c\xed\x97\xa4\xeb\x9e\x80\xeb\xa1\x9c48\xea\xb8\xb8</\xeb\x8f\x84\xeb\xa1\x9c\xeb\xaa\x85><\xeb\x8f\x84\xeb\xa1\x9c\xeb\xaa\x85\xea\xb1\xb4\xeb\xac\xbc\xeb\xb3\xb8\xeb\xb2\x88\xed\x98\xb8\xec\xbd\x94\xeb\x93\x9c>00010</\xeb\x8f\x84\xeb\xa1\x9c\xeb\xaa\x85\xea\xb1\xb4\xeb\xac\xbc\xeb\xb3\xb8\xeb\xb2\x88\xed\x98\xb8\xec\xbd\x94\xeb\x93\x9c><\xeb\x8f\x84\xeb\xa1\x9c\xeb\xaa\x85\xea\x
# ...

# %%
resp.content.decode('utf-8')
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    74,000</거래금액><거래유형>중개거래</거래유형><건축년도>2004</건축년도><년>2022</년><도로명>테헤란로48길</도로명><도로명건물본번호코드>00010</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166742</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0707</법정동본번코드><법정동부번코드>0018</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼우정에쉐르2</아파트><월>12</월><일>17</일><일련번호>11680-493</일련번호><전용면적>49.38</전용면적><중개사소재지>서울 강남구</중개사소재지><지번>707-18</지번><지역코드>11680</지역코드><층>9</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    32,000</거래금액><거래유형>중개거래</거래유형><건축년도>2002</건축년도><년>2022</년><도로명>언주로</도로명><도로명건물본번호코드>00427</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3005086</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0720
# ...

# %%
import xmltodict

# %%
xmltodict.parse(resp.content.decode('utf-8'))
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'거래금액': '74,000',
#       '거래유형': '중개거래',
#       '건축년도': '2004',
#       '년': '2022',
#       '도로명': '테헤란로48길',
#       '도로명건물본번호코드': '00010',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11680',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4166742',
#       '법정동': '역삼동',
#       '법정동본번코드': '0707',
#       '법정동부번코드': '0018',
#       '법정동시군구코드': '11680',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '역삼우정에쉐르2',
#       '월': '12',
#       '일': '17',
#       '일련번호': '11680-493',
#       '전용면적': '49.38',
#       '중개사소재지': '서울 강남구',
#       '지번': '707-18',
#       '지역코드': '11680',
#       '층': '9',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '32,000',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2022',
#       '도로명': '언주로',
#       '도로명건물본번호코드': '00427',
#       '도로명건물부번호코드': '00000',
# ...

# %%
data = xmltodict.parse(resp.content.decode('utf-8'))

# %%
data['response']['body']['items']['item']
# Out:
# [{'거래금액': '74,000',
#   '거래유형': '중개거래',
#   '건축년도': '2004',
#   '년': '2022',
#   '도로명': '테헤란로48길',
#   '도로명건물본번호코드': '00010',
#   '도로명건물부번호코드': '00000',
#   '도로명시군구코드': '11680',
#   '도로명일련번호코드': '01',
#   '도로명지상지하코드': '0',
#   '도로명코드': '4166742',
#   '법정동': '역삼동',
#   '법정동본번코드': '0707',
#   '법정동부번코드': '0018',
#   '법정동시군구코드': '11680',
#   '법정동읍면동코드': '10100',
#   '법정동지번코드': '1',
#   '아파트': '역삼우정에쉐르2',
#   '월': '12',
#   '일': '17',
#   '일련번호': '11680-493',
#   '전용면적': '49.38',
#   '중개사소재지': '서울 강남구',
#   '지번': '707-18',
#   '지역코드': '11680',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '32,000',
#   '거래유형': '중개거래',
#   '건축년도': '2002',
#   '년': '2022',
#   '도로명': '언주로',
#   '도로명건물본번호코드': '00427',
#   '도로명건물부번호코드': '00000',
#   '도로명시군구코드': '11680',
#   '도로명일련번호코드': '01',
#   '도로명지상지하코드': '0',
#   '도로명코드': '3005086',
#   '법정동': '역삼동',
#   '법정동본번코드': '0720',
#   '법정동부번코드': '0025',
#   '법정동시군구코드': '11680',
#   '법정동읍면동코드': '10100',
#   '법정동지번코드': '1',
#   '아파트': '대우디오빌',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(data['response']['body']['items']['item'])
df
# Out:
#       거래금액  거래유형  건축년도     년      도로명 도로명건물본번호코드 도로명건물부번호코드 도로명시군구코드  \
# 0   74,000  중개거래  2004  2022  테헤란로48길      00010      00000    11680
# 1   32,000  중개거래  2002  2022      언주로      00427      00000    11680
# 2   32,000  중개거래  2002  2022      언주로      00427      00000    11680
# 3  290,000  중개거래  2022  2022  테헤란로44길      00026      00000    11680
# 4   70,000   직거래  2005  2022  언주로103길      00016      00000    11680
# 5   70,000   직거래  2005  2022  언주로103길      00016      00000    11680
# 6  241,000  중개거래  2019  2022      선릉로      00008      00000    11680
# 7  100,000  중개거래  1992  2022  개포로109길      00021      00000    11680
# 8  190,000  중개거래  1983  2022      개포로      00516      00000    11680
# 9  220,000  중개거래  2019  2022      삼성로      00011      00000    11680
#
#   도로명일련번호코드 도로명지상지하코드  ...   월   일        일련번호     전용면적  중개사소재지      지번  \
# 0        01         0  ...  12  17   11680-493    49.38  서울 강남구  707-18
# ...

# %%
df.to_csv('table.csv',encoding='utf-8-sig')
